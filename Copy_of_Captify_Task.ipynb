# %% [markdown]
# <a href="https://colab.research.google.com/github/CHIZIGWE/TSK/blob/main/Copy_of_Captify_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Solution Notebook**

# %% [markdown]
# **Loading Libraries**

# %%
#Importing data wrangling and visualisation libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from numpy.ma.core import outer
from decimal import Decimal

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

from datetime import  datetime as dt
from dateutil import relativedelta
pd.options.display.float_format = '{:.4f}'.format #To suppress scientific notation

# %%
#Loading the three datasets
Deal_Performance = pd.read_excel(r'/content/drive/MyDrive/Captify_Task/deal-performance-data.xlsx')

bid_blue = pd.read_csv(r"/content/drive/MyDrive/Captify_Task/deal-bid-data-bluessp.csv")

bid_red = pd.read_csv(r"/content/drive/MyDrive/Captify_Task/deal-bid-data-redssp.csv")

# %% [markdown]
# Sanity Check

# %%
#Creating Function to Automate Sanity Check
def sanity_check(Dataset, Dataset_Name):
    print(Dataset_Name, 'Sanity Check: \n\n')
    print(f'{Dataset_Name} Rows and Columns: \n' ,Dataset.shape, '\n')
    print(f'{Dataset_Name} Column information: \n')
    Dataset.info()
    print('\n')
    print(f'{Dataset_Name} Missing information: \n',Dataset.isnull().sum(), '\n')
    print(f'{Dataset_Name} Statistical Summary: \n',Dataset.describe(), '\n')
    print(f'End of {Dataset_Name} sanity check \n')

# %%
#Sanity Check for Bid Red
sanity_check(bid_red, 'Bid Red')
# Out:
# Bid Red Sanity Check:
#
#
# Bid Red Rows and Columns:
#  (1132, 4)
#
# Bid Red Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132 entries, 0 to 1131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      1132 non-null   object
#  1   month        1132 non-null   object
#  2   bid_request  1132 non-null   float64
#  3   bids         1132 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 35.5+ KB
#
#
# Bid Red Missing information:
#  deal_id        0
# month          0
# bid_request    0
# bids           0
# dtype: int64
#
# Bid Red Statistical Summary:
#              bid_request             bids
# count         1132.0000        1132.0000
# mean   95372278085.9488  5870149054.8701
# std   110894431149.7836  7107228982.1820
# min            160.0000           0.0000
# 25%            160.0000           0.0000
# 50%    55682516225.5000  3144363396.0000
# 75%   163250000000.0000 10365478039.2500
# max   557000000000.0000 44441690515.0000
#
# End of Bid Red sanity check

# %%
#Bid bld blue Sanity Check
sanity_check(bid_blue, 'Bid Blue')
# Out:
# Bid Blue Sanity Check:
#
#
# Bid Blue Rows and Columns:
#  (748, 4)
#
# Bid Blue Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      748 non-null    object
#  1   month        748 non-null    object
#  2   bid_request  748 non-null    float64
#  3   bids         748 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.5+ KB
#
#
# Bid Blue Missing information:
#  deal_id        0
# month          0
# bid_request    0
# bids           0
# dtype: int64
#
# Bid Blue Statistical Summary:
#              bid_request             bids
# count          748.0000         748.0000
# mean   83372563851.8302  6156973885.0214
# std   104246600250.1387  7556392469.1714
# min            160.0000           0.0000
# 25%            160.0000           0.0000
# 50%    34921890202.0000  3133102090.0000
# 75%   143500000000.0000 10501080076.2500
# max   476000000000.0000 37064307785.0000
#
# End of Bid Blue sanity check

# %%
#Deal Performance sanity check
sanity_check(Deal_Performance, 'Deal Performance')
# Out:
# Deal Performance Sanity Check:
#
#
# Deal Performance Rows and Columns:
#  (1980, 19)
#
# Deal Performance Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   deal_id          1980 non-null   object
#  1   deal_name        1980 non-null   object
#  2   month            1980 non-null   datetime64[ns]
#  3   segment_type     1980 non-null   object
#  4   ssp              1980 non-null   object
#  5   advertiser       1980 non-null   object
#  6   vertical         1980 non-null   object
#  7   office           1980 non-null   object
#  8   tier             1980 non-null   object
#  9   media_type       1980 non-null   object
#  10  kpi              1980 non-null   object
#  11  kpi_value        1980 non-null   float64
#  12  gross_spend      1980 non-null   float64
#  13  media_cost       1980 non-null   float64
#  14  data_revenue     1980 non-null   float64
#  15  impressions      1980 non-null   int64
#  16  video_completes  1980 non-null   float64
#  17  clicks           1980 non-null   float64
#  18  media_margin     1980 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(10)
# memory usage: 294.0+ KB
#
#
# Deal Performance Missing information:
#  deal_id            0
# deal_name          0
# month              0
# segment_type       0
# ssp                0
# advertiser         0
# vertical           0
# office             0
# tier               0
# media_type         0
# kpi                0
# kpi_value          0
# gross_spend        0
# media_cost         0
# data_revenue       0
# impressions        0
# video_completes    0
# clicks             0
# media_margin       0
# dtype: int64
#
# Deal Performance Statistical Summary:
#                                 month  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes    clicks  media_margin
# count                           1980  1980.0000    1980.0000   1980.0000     1980.0000    1980.0000        1980.0000 1980.0000     1980.0000
# mean   2024-07-15 23:54:10.909090816    23.9216      97.6997     48.8781       48.8215   48248.5778       23302.1712   55.9100       47.3567
# min              2024-01-01 00:00:00     0.1000       0.6924      0.3484        0.1472       1.0000           0.9000    0.0050       17.5758
# 25%              2024-04-01 00:00:00     0.3500       1.1612      0.6507        0.5297       1.0000           1.0000    0.1469       39.9951
# 50%              2024-08-01 00:00:00     4.0000       4.9541      2.4731        2.4818   20447.0000        7628.0000   15.8431       48.0831
# 75%              2024-11-01 00:00:00    60.0000     136.2126     66.6534       66.2603   85027.5000       40334.0000   94.6009       54.5661
# max              2025-02-01 00:00:00    90.0000    1951.7085   1330.4021      728.8125  350304.0000      210182.4000  399.0000       65.0000
# std                              NaN    34.7902     180.5666     98.8399       89.8358   60927.9137       31290.7554   74.2719       10.5522
#
# End of Deal Performance sanity check

# %% [markdown]
# The Datasets are mostly clean.
#
# However, in the bid datasets, the column depicting the respective bids' dates is an object datatype.
#
# This has to be changed to allow seamless integration with the larger Deal performance dataset.

# %%
#Converting both to datetime datatypes
bid_red['month'] = pd.to_datetime(bid_red['month'])
bid_blue['month'] = pd.to_datetime(bid_blue['month'])

# %%
#Checking that datatype has taken place
bid_blue.info()
print('\n')
bid_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      748 non-null    object
#  1   month        748 non-null    datetime64[ns]
#  2   bid_request  748 non-null    float64
#  3   bids         748 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 23.5+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132 entries, 0 to 1131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      1132 non-null   object
#  1   month        1132 non-null   datetime64[ns]
#  2   bid_request  1132 non-null   float64
#  3   bids         1132 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 35.5+ KB

# %% [markdown]
# Check the first five rows of the bid dataset to confirm structural changes

# %%
bid_red.head()
# Out:
#     deal_id      month      bid_request        bids
# 0  Deal_149 2024-01-01         160.0000           0
# 1  Deal_149 2024-01-05         160.0000  2320359348
# 2  Deal_222 2024-01-02 45169671695.0000  6431140982
# 3  Deal_222 2024-01-04 74806028011.0000  5821454587
# 4  Deal_222 2024-01-09 68845194016.0000           0

# %%
bid_blue.head()
# Out:
#     deal_id      month       bid_request         bids
# 0  Deal_102 2024-01-01          160.0000  11418560961
# 1  Deal_102 2024-01-02          160.0000   4218636088
# 2  Deal_102 2024-01-04 287000000000.0000   7902414504
# 3  Deal_102 2024-01-05          160.0000  30286237905
# 4  Deal_102 2024-01-06 201000000000.0000            0

# %% [markdown]
# To develop a full picture of the bidding metrics we concatenate the datasets

# %%
#Concatenating the bid Datasets
combined_bid = pd.concat([bid_blue, bid_red])

# %%
#Sanity Check on the Concatenated Dataset
sanity_check(combined_bid, 'Combined Bid')
# Out:
# Combined Bid Sanity Check:
#
#
# Combined Bid Rows and Columns:
#  (1880, 4)
#
# Combined Bid Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1880 entries, 0 to 1131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      1880 non-null   object
#  1   month        1880 non-null   datetime64[ns]
#  2   bid_request  1880 non-null   float64
#  3   bids         1880 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 73.4+ KB
#
#
# Combined Bid Missing information:
#  deal_id        0
# month          0
# bid_request    0
# bids           0
# dtype: int64
#
# Combined Bid Statistical Summary:
#                                 month       bid_request             bids
# count                           1880         1880.0000        1880.0000
# mean   2024-02-22 22:56:25.531914752  90597923699.1824  5984268721.3346
# min              2024-01-01 00:00:00          160.0000           0.0000
# 25%              2024-01-04 00:00:00          160.0000           0.0000
# 50%              2024-01-07 00:00:00  48618907570.5000  3133102090.0000
# 75%              2024-01-11 00:00:00 157000000000.0000 10454115784.5000
# max              2025-01-02 00:00:00 557000000000.0000 44441690515.0000
# std                              NaN 108429505967.0455  7288618647.0271
#
# End of Combined Bid sanity check

# %%
#First Five rows of newly formulated Data set
combined_bid.head()
# Out:
#     deal_id      month       bid_request         bids
# 0  Deal_102 2024-01-01          160.0000  11418560961
# 1  Deal_102 2024-01-02          160.0000   4218636088
# 2  Deal_102 2024-01-04 287000000000.0000   7902414504
# 3  Deal_102 2024-01-05          160.0000  30286237905
# 4  Deal_102 2024-01-06 201000000000.0000            0

# %% [markdown]
# Exploring the Deal Performance Dataset to see opportunities for Data manipulation and wrangling.

# %%
Deal_Performance.head()
# Out:
#     deal_id          deal_name      month segment_type      ssp    advertiser            vertical office         tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin
# 0  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159
# 1  Deal_102  Deal_102_Campaign 2024-02-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC     6.0000     153.7440    110.2982       43.4458         9900       12508.0000  18.3830       28.2585
# 2  Deal_102  Deal_102_Campaign 2024-04-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1000     142.5671    101.2508       41.3163        21614           1.0000  21.6140       28.9803
# 3  Deal_102  Deal_102_Campaign 2024-05-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC     4.0000     164.7459     97.4830       67.2628        81433           1.0000  24.3708       40.8282
# 4  Deal_102  Deal_102_Campaign 2024-06-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1000     172.8855    101.1058       71.7798        89362       41537.0000  89.3620       41.5187

# %% [markdown]
# Given that KPIs and their respecive values could form an integral part of the necessary analysis. The respective KPIs within the dataset should become variables alongside the existing variables.

# %%
#First we created a pivot based on the advertiser and the various KPIs
pivoted = Deal_Performance.pivot_table(index = 'advertiser', columns = 'kpi', values = 'kpi_value').reset_index()

#Then we Merge this Deal Performance dataframe
Deal_Performance = pd.merge(Deal_Performance, pivoted, how= 'inner', on= 'advertiser')

# %%
#The First ten rows of the new dataframe
Deal_Performance.head()
# Out:
#     deal_id          deal_name      month segment_type      ssp    advertiser            vertical office         tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin    CPC    CTR  VTR
# 0  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159 5.0000 0.1180  NaN
# 1  Deal_102  Deal_102_Campaign 2024-02-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC     6.0000     153.7440    110.2982       43.4458         9900       12508.0000  18.3830       28.2585 5.0000 0.1180  NaN
# 2  Deal_102  Deal_102_Campaign 2024-04-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1000     142.5671    101.2508       41.3163        21614           1.0000  21.6140       28.9803 5.0000 0.1180  NaN
# 3  Deal_102  Deal_102_Campaign 2024-05-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC     4.0000     164.7459     97.4830       67.2628        81433           1.0000  24.3708       40.8282 5.0000 0.1180  NaN
# 4  Deal_102  Deal_102_Campaign 2024-06-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1000     172.8855    101.1058       71.7798        89362       41537.0000  89.3620       41.5187 5.0000 0.1180  NaN

# %% [markdown]
# Above we can see that the dataframe has successfully incorporated the KPIs as part of the variables.

# %% [markdown]
# **Combining the Deal Performance dataset and the Concatenated bid dataset**

# %%
Data = pd.merge(Deal_Performance, combined_bid, how= 'inner', on= 'deal_id')

# %%
#First five rows of new dataset

print(Data.head())
# Out:
#     deal_id          deal_name    month_x segment_type      ssp    advertiser            vertical office         tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin    CPC    CTR  VTR    month_y       bid_request         bids
# 0  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159 5.0000 0.1180  NaN 2024-01-01          160.0000  11418560961
# 1  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159 5.0000 0.1180  NaN 2024-01-02          160.0000   4218636088
# 2  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159 5.0000 0.1180  NaN 2024-01-04 287000000000.0000   7902414504
# 3  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159 5.0000 0.1180  NaN 2024-01-05          160.0000  30286237905
# 4  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR     0.1900     154.7609    109.2366       45.5243        66474       50812.0000 126.3006       29.4159 5.0000 0.1180  NaN 2024-01-06 201000000000.0000            0

# %% [markdown]
# Sanity Check for combined Dataset

# %%
sanity_check(Data, 'Combined Dataset')
# Out:
# Combined Dataset Sanity Check:
#
#
# Combined Dataset Rows and Columns:
#  (15931, 25)
#
# Combined Dataset Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   deal_id          15931 non-null  object
#  1   deal_name        15931 non-null  object
#  2   month_x          15931 non-null  datetime64[ns]
#  3   segment_type     15931 non-null  object
#  4   ssp              15931 non-null  object
#  5   advertiser       15931 non-null  object
#  6   vertical         15931 non-null  object
#  7   office           15931 non-null  object
#  8   tier             15931 non-null  object
#  9   media_type       15931 non-null  object
#  10  kpi              15931 non-null  object
#  11  kpi_value        15931 non-null  float64
#  12  gross_spend      15931 non-null  float64
#  13  media_cost       15931 non-null  float64
#  14  data_revenue     15931 non-null  float64
#  15  impressions      15931 non-null  int64
#  16  video_completes  15931 non-null  float64
#  17  clicks           15931 non-null  float64
#  18  media_margin     15931 non-null  float64
#  19  CPC              11155 non-null  float64
#  20  CTR              15723 non-null  float64
#  21  VTR              12759 non-null  float64
#  22  month_y          15931 non-null  datetime64[ns]
#  23  bid_request      15931 non-null  float64
#  24  bids             15931 non-null  int64
# dtypes: datetime64[ns](2), float64(11), int64(2), object(10)
# memory usage: 3.0+ MB
#
#
# Combined Dataset Missing information:
#  deal_id               0
# deal_name             0
# month_x               0
# segment_type          0
# ssp                   0
# advertiser            0
# vertical              0
# office                0
# tier                  0
# media_type            0
# kpi                   0
# kpi_value             0
# gross_spend           0
# media_cost            0
# data_revenue          0
# impressions           0
# video_completes       0
# clicks                0
# media_margin          0
# CPC                4776
# CTR                 208
# VTR                3172
# month_y               0
# bid_request           0
# bids                  0
# dtype: int64
#
# Combined Dataset Statistical Summary:
#                               month_x  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes     clicks  media_margin        CPC        CTR        VTR                        month_y       bid_request             bids
# count                          15931 15931.0000   15931.0000  15931.0000    15931.0000   15931.0000       15931.0000 15931.0000    15931.0000 11155.0000 15723.0000 12759.0000                          15931        15931.0000       15931.0000
# mean   2024-07-18 15:01:22.028749056    23.6397      77.8641     37.7704       40.0937   48284.8003       23401.2548    56.1048       47.5602     4.3658     0.3091    74.2670  2024-02-24 12:31:30.050844160  92012202634.3476  6017993065.9367
# min              2024-01-01 00:00:00     0.1000       0.6924      0.3484        0.1472       1.0000           0.9000     0.0050       17.5758     4.0000     0.1000    60.0000            2024-01-01 00:00:00          160.0000           0.0000
# 25%              2024-04-01 00:00:00     0.3200       0.9947      0.5615        0.4637       1.0000           1.0000     0.1401       40.4309     4.0000     0.2700    70.0000            2024-01-04 00:00:00          160.0000           0.0000
# 50%              2024-08-01 00:00:00     4.0000       4.7353      2.2603        2.4184   21088.0000        7815.0000    15.0140       48.1946     4.0000     0.3050    75.0000            2024-01-07 00:00:00  52461854203.0000  3236453327.0000
# 75%              2024-11-01 00:00:00    60.0000     125.6437     59.5200       58.7482   85287.0000       40633.0000    95.0410       54.8823     4.6037     0.3543    78.0000            2024-01-11 00:00:00 158000000000.0000 10557252821.0000
# max              2025-02-01 00:00:00    90.0000    1951.7085   1330.4021      728.8125  350304.0000      210182.4000   399.0000       65.0000     6.0000     0.5000    90.0000            2025-01-02 00:00:00 557000000000.0000 44441690515.0000
# std                              NaN    34.6096     134.2586     69.2800       70.9526   60635.9438       31109.9141    74.7152       10.5317     0.4867     0.0761     6.5598                            NaN 108743103584.7491  7237083835.1465
#
# End of Combined Dataset sanity check

# %% [markdown]
# Most of the columns have all no missing values
#
# However, given the fact that some of the advertiser do not use all forms of KPI (CPC. CTR, VTR). There will null value for some KPI measurements.
# We wil be rectifying this by imputing the number zero in place of the 'Nan' value, dropping the additional 'month' column and renaming the sole 'monthh' column to date.

# %%
Data.fillna(0, inplace= True)
Data.rename(columns= {'month_x': 'Date'}, inplace= True)
Data.drop(columns= ['kpi', 'kpi_value'], inplace= True)

# %%
#Final Sanity Check

sanity_check(Data, 'Combined Dataset')
# Out:
# Combined Dataset Sanity Check:
#
#
# Combined Dataset Rows and Columns:
#  (15931, 23)
#
# Combined Dataset Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   deal_id           15931 non-null  object
#  1   deal_name         15931 non-null  object
#  2   Date              15931 non-null  datetime64[ns]
#  3   segment_type      15931 non-null  object
#  4   ssp               15931 non-null  object
#  5   advertiser        15931 non-null  object
#  6   vertical          15931 non-null  object
#  7   office            15931 non-null  object
#  8   tier              15931 non-null  object
#  9   media_type        15931 non-null  object
#  10  gross_spend       15931 non-null  float64
#  11  media_cost        15931 non-null  float64
#  12  data_revenue      15931 non-null  float64
#  13  impressions       15931 non-null  int64
#  14  video_completes   15931 non-null  float64
#  15  clicks            15931 non-null  float64
#  16  media_margin      15931 non-null  float64
#  17  CPC               15931 non-null  float64
#  18  CTR               15931 non-null  float64
#  19  VTR               15931 non-null  float64
#  20  bid_request       15931 non-null  float64
#  21  bids              15931 non-null  int64
#  22  Bid_Success_Rate  15931 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(2), object(9)
# memory usage: 2.8+ MB
#
#
# Combined Dataset Missing information:
#  deal_id             0
# deal_name           0
# Date                0
# segment_type        0
# ssp                 0
# advertiser          0
# vertical            0
# office              0
# tier                0
# media_type          0
# gross_spend         0
# media_cost          0
# data_revenue        0
# impressions         0
# video_completes     0
# clicks              0
# media_margin        0
# CPC                 0
# CTR                 0
# VTR                 0
# bid_request         0
# bids                0
# Bid_Success_Rate    0
# dtype: int64
#
# Combined Dataset Statistical Summary:
#                                  Date  gross_spend  media_cost  data_revenue  impressions  video_completes     clicks  media_margin        CPC        CTR        VTR       bid_request             bids  Bid_Success_Rate
# count                          15931   15931.0000  15931.0000    15931.0000   15931.0000       15931.0000 15931.0000    15931.0000 15931.0000 15931.0000 15931.0000        15931.0000       15931.0000        15931.0000
# mean   2024-07-18 15:01:22.028749056      77.8641     37.7704       40.0937   48284.8003       23401.2548    56.1048       47.5602     3.0570     0.3050    59.4798  92012202634.3476  6017993065.9367               inf
# min              2024-01-01 00:00:00       0.6924      0.3484        0.1472       1.0000           0.9000     0.0050       17.5758     0.0000     0.0000     0.0000          160.0000           0.0000            0.0000
# 25%              2024-04-01 00:00:00       0.9947      0.5615        0.4637       1.0000           1.0000     0.1401       40.4309     0.0000     0.2600    63.0000          160.0000           0.0000            1.5093
# 50%              2024-08-01 00:00:00       4.7353      2.2603        2.4184   21088.0000        7815.0000    15.0140       48.1946     4.0000     0.3050    72.0000  52461854203.0000  3236453327.0000           27.9585
# 75%              2024-11-01 00:00:00     125.6437     59.5200       58.7482   85287.0000       40633.0000    95.0410       54.8823     4.5000     0.3543    76.6667 158000000000.0000 10557252821.0000               NaN
# max              2025-02-01 00:00:00    1951.7085   1330.4021      728.8125  350304.0000      210182.4000   399.0000       65.0000     6.0000     0.5000    90.0000 557000000000.0000 44441690515.0000               inf
# std                              NaN     134.2586     69.2800       70.9526   60635.9438       31109.9141    74.7152       10.5317     2.0414     0.0833    30.2334 108743103584.7491  7237083835.1465               NaN
#
# End of Combined Dataset sanity check
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:4779: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %% [markdown]
# **Data Aggregation**
#
# Now we have successfully combined and cleaned the three datasets. It is time to construct an aggregated dataset that summarises the data of the various advertisers to conduct analysis and further investigations.

# %%
#Firstly we will create a calculated column to describe the bid success rate
Data['bid_success_rate'] = Data['bids']/Data['bid_request']
#Now we create an aggregated dataset
Data_Agg = Data.groupby(['advertiser']).agg({'segment_type': pd.Series.mode, 'vertical': pd.Series.mode, 'tier': pd.Series.mode, 'media_type': pd.Series.mode, 'Date':'max', 'gross_spend': 'sum', 'media_cost': 'sum',
                                            'impressions': 'sum', 'video_completes': 'sum', 'clicks': 'sum', 'CPC': 'mean', 'CTR':'mean', 'VTR':'mean', 'bid_request': 'sum', 'bids': 'sum', 'bid_success_rate': 'mean'})

# %%
#First rows of new dataset
Data_Agg.head()
# Out:
#                segment_type            vertical                     tier media_type       Date  gross_spend  media_cost  impressions  video_completes     clicks    CPC    CTR     VTR         bid_request           bids  bid_success_rate
# advertiser
# Advertiser_1     Cookieless  Jobs and Education              Growth Tier    Display 2024-12-01   12704.9647   8471.1944      3559860     2189673.0000  3353.1033 5.0000 0.1180  0.0000  6022480321404.0000   612203155209     31891274.3058
# Advertiser_10    Cookieless              Retail  Below Minimum Threshold      Video 2025-02-01   14934.1773   7343.7211     10494118     4413376.7152 20731.6747 4.0000 0.2567 77.9873 22720722647728.0000  1333345362683      5718628.4569
# Advertiser_100   Cookieless              Travel                 Mid-Tier      Video 2025-02-01    6714.4144   2745.4528     19135059    12459698.9344 12722.2832 4.0000 0.2953 70.7691 24843172032477.0000  2351876589913     20344455.6362
# Advertiser_101   Cookieless             Alcohol              White Glove      Video 2025-02-01     169.3549     92.4728      5992370     2025564.6000  7631.2030 4.0000 0.3083 75.0000 16386449370972.0000  1516421046670     15608215.0732
# Advertiser_102       Cookie   Style and Fashion  Below Minimum Threshold      Video 2024-12-01      60.1559     35.2049      1376988      881890.8552  2532.8700 0.0000 0.3567 74.1300  2616000002880.0000   185088475542     15781298.4724

# %%
#Sanity Check
sanity_check(Data_Agg, 'Aggregated Dataset')
# Out:
# Aggregated Dataset Sanity Check:
#
#
# Aggregated Dataset Rows and Columns:
#  (181, 16)
#
# Aggregated Dataset Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 181 entries, Advertiser_1 to Advertiser_99
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   segment_type      181 non-null    object
#  1   vertical          181 non-null    object
#  2   tier              181 non-null    object
#  3   media_type        181 non-null    object
#  4   Date              181 non-null    datetime64[ns]
#  5   gross_spend       181 non-null    float64
#  6   media_cost        181 non-null    float64
#  7   impressions       181 non-null    int64
#  8   video_completes   181 non-null    float64
#  9   clicks            181 non-null    float64
#  10  CPC               181 non-null    float64
#  11  CTR               181 non-null    float64
#  12  VTR               181 non-null    float64
#  13  bid_request       181 non-null    float64
#  14  bids              181 non-null    int64
#  15  bid_success_rate  181 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(4)
# memory usage: 24.0+ KB
#
#
# Aggregated Dataset Missing information:
#  segment_type        0
# vertical            0
# tier                0
# media_type          0
# Date                0
# gross_spend         0
# media_cost          0
# impressions         0
# video_completes     0
# clicks              0
# CPC                 0
# CTR                 0
# VTR                 0
# bid_request         0
# bids                0
# bid_success_rate    0
# dtype: int64
#
# Aggregated Dataset Statistical Summary:
#                                  Date  gross_spend  media_cost   impressions  video_completes     clicks      CPC      CTR      VTR         bid_request               bids  bid_success_rate
# count                            181     181.0000    181.0000      181.0000         181.0000   181.0000 181.0000 181.0000 181.0000            181.0000           181.0000          181.0000
# mean   2024-10-28 18:01:59.337016576    6853.3335   3324.4222  4249862.7293     2059698.2878  4938.1486   2.3888   0.2952  49.6431  8098598895954.6523  529683135543.8563     13342495.9374
# min              2024-01-01 00:00:00       9.1010      4.5481        1.0000           0.9000     0.0050   0.0000   0.0000   0.0000            160.0000             0.0000            0.0000
# 25%              2024-08-01 00:00:00      79.0223     40.3265   557082.0000      225990.8000   732.0898   0.0000   0.2333   0.0000  1074047977012.0000   79476587590.0000      1158957.9895
# 50%              2025-01-01 00:00:00    1732.1654    897.5433  2417175.0000     1012193.4000  2620.3867   4.0000   0.3000  70.0000  4724652551488.0000  265502920800.0000     11286335.6329
# 75%              2025-02-01 00:00:00    8629.0060   4292.7322  5992370.0000     3190507.0000  7562.4444   4.0000   0.3733  76.6667 13562499234870.0000  849481720839.0000     19371829.2427
# max              2025-02-01 00:00:00   59842.5847  30404.0720 20854452.0000    12459698.9344 30393.1948   6.0000   0.5000  90.0000 40168696982964.0000 2538746594866.0000     82157647.4234
# std                              NaN   11095.3515   5367.1819  4853021.8236     2500323.2457  5690.8093   2.2525   0.1318  36.1775  8823347869108.1016  595180324781.1299     13498359.0447
#
# End of Aggregated Dataset sanity check

# %% [markdown]
# There is no misssing data.
#
# Now we create a Column to assess churn v unchurned customers.

# %%
#Firstly, we create a variable called current time
current_time = dt.now()

#Then we create a column to stating the difference between today, and the last transaction

Data_Agg['months_since_last_transaction'] = round((current_time - Data_Agg['Date']).dt.days/30, 1)


#Given the business rule that customers with a most recent purchase date of more than 6 months are considered churned.

Data_Agg['churned'] = np.where(Data_Agg['months_since_last_transaction'] > 6, 1, 0)

# %%
#Final Dataset
Data_Agg.head()
# Out:
#                segment_type            vertical                     tier       Date  gross_spend  media_cost  impressions  video_completes     clicks    CPC    CTR     VTR         bid_request           bids  bid_success_rate  days_since_last_transaction  Churned  months_since_last_transaction
# advertiser
# Advertiser_1     Cookieless  Jobs and Education              Growth Tier 2024-12-01   12704.9647   8471.1944      3559860     2189673.0000  3353.1033 5.0000 0.1180  0.0000  6022480321404.0000   612203155209     31891274.3058                       3.6000        0                         3.6000
# Advertiser_10    Cookieless              Retail  Below Minimum Threshold 2025-02-01   14934.1773   7343.7211     10494118     4413376.7152 20731.6747 4.0000 0.2567 77.9873 22720722647728.0000  1333345362683      5718628.4569                       1.6000        0                         1.6000
# Advertiser_100   Cookieless              Travel                 Mid-Tier 2025-02-01    6714.4144   2745.4528     19135059    12459698.9344 12722.2832 4.0000 0.2953 70.7691 24843172032477.0000  2351876589913     20344455.6362                       1.6000        0                         1.6000
# Advertiser_101   Cookieless             Alcohol              White Glove 2025-02-01     169.3549     92.4728      5992370     2025564.6000  7631.2030 4.0000 0.3083 75.0000 16386449370972.0000  1516421046670     15608215.0732                       1.6000        0                         1.6000
# Advertiser_102       Cookie   Style and Fashion  Below Minimum Threshold 2024-12-01      60.1559     35.2049      1376988      881890.8552  2532.8700 0.0000 0.3567 74.1300  2616000002880.0000   185088475542     15781298.4724                       3.6000        0                         3.6000

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# This section is broken into three sections, distinctively, Univariate, Bivariate and Multivariate. The Objective is to analyse the created Dataset in order assess the Hypotheses, Formulate new ones and prepare the Data for further statistical analysis.

# %% [markdown]
# Univariate Analysis

# %%
#Creating a function to automate the creation of Histogram Boxplots

def Histogram_Boxplot(Dataset, Variable, Title, Color1, Color2):
  fig, ax = plt.subplots(ncols= 1, nrows= 2, figsize= (10,10), showmean = True)

  sns.histplot(data = Dataset, x= Variable, ax= ax[0], color = Color1)
  plt.title(Title)


  sns.boxplot(data = Dataset, x= Variable, ax= ax[1], color = Color2)
  plt.show()

# %%
#Creating a function to automate the cration of

# %%
Histogram_Boxplot(Dataset= Data_Agg, Variable = 'CTR', Title = 'CTR Histogram_Boxplot', Color1 = 'blue', Color2 = 'green')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-a6b839ea93ba> in <cell line: 0>()
# ----> 1 Histogram_Boxplot(Dataset= Data_Agg, Variable = 'CTR', Title = 'CTR Histogram_Boxplot', Color1 = 'blue', Color2 = 'green')
#
# <ipython-input-87-1dff93d7aa1e> in Histogram_Boxplot(Dataset, Variable, Title, Color1, Color2)
#       2
#       3 def Histogram_Boxplot(Dataset, Variable, Title, Color1, Color2):
# ----> 4   fig, ax = plt.subplots(ncols= 1, nrows= 2, figsize= (10,10), showmean = True)
#       5
#       6   sns.histplot(data = Dataset, x= Variable, ax= ax[0], color = Color1)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1773
#    1774     """
# -> 1775     fig = figure(**fig_kw)
#    1776     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1777                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1040                 RuntimeWarning)
#    1041
# -> 1042         manager = new_figure_manager(
#    1043             num, figsize=figsize, dpi=dpi,
#    1044             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     550     """Create a new figure manager instance."""
#     551     _warn_if_gui_out_of_main_thread()
# --> 552     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#     553
#     554
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in new_figure_manager(num, FigureClass, *args, **kwargs)
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#      28
#      29
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2558             %(Figure:kwdoc)s
#    2559         """
# -> 2560         super().__init__(**kwargs)
#    2561         self._root_figure = self
#    2562         self._layout_engine = None
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in __init__(self, **kwargs)
#     152         self.stale = True
#     153         self.suppressComposite = None
# --> 154         self.set(**kwargs)
#     155
#     156     def _get_draw_artists(self, renderer):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     144             return
#     145
# --> 146         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147         cls.set.__name__ = "set"
#     148         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1239         # Artist._update_set_signature_and_docstring() at the end of the
#    1240         # module.
# -> 1241         return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#    1242
#    1243     @contextlib.contextmanager
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1231         The lack of prenormalization is to maintain backcompatibility.
#    1232         """
# -> 1233         return self._update_props(
#    1234             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235             "{prop_name!r}")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1204                     func = getattr(self, f"set_{k}", None)
#    1205                     if not callable(func):
# -> 1206                         raise AttributeError(
#    1207                             errfmt.format(cls=type(self), prop_name=k),
#    1208                             name=k)
#
# AttributeError: Figure.set() got an unexpected keyword argument 'showmean'
