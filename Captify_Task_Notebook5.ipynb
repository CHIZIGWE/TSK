# %% [markdown]
# <a href="https://colab.research.google.com/github/CHIZIGWE/TSK/blob/main/Captify_Task_Notebook5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preparation & Aggregation

# %% [markdown]
# This section will involve looking at the datasets separately, conducting data manipulation where appropriate and eventually combine all three datasets to develop a bigger picture.

# %%
#Importing data wrangling and visualisation libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from numpy.ma.core import outer
from decimal import Decimal

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

from datetime import  datetime as dt
from dateutil import relativedelta
pd.options.display.float_format = '{:.2f}'.format #To format numerical output

# %%
#Loading the three datasets
Deal_Performance = pd.read_excel(r'/content/drive/MyDrive/Captify_Task/deal-performance-data.xlsx')

bid_blue = pd.read_csv(r"/content/drive/MyDrive/Captify_Task/deal-bid-data-bluessp.csv")

bid_red = pd.read_csv(r"/content/drive/MyDrive/Captify_Task/deal-bid-data-redssp.csv")

# %%
#Creating Function to Automate Sanity Check
def sanity_check(Dataset, Dataset_Name):
    print(Dataset_Name, 'Sanity Check: \n\n')
    print(Dataset.head()), '\n'
    print(f'{Dataset_Name} Rows and Columns: \n' ,Dataset.shape, '\n')
    print(f'{Dataset_Name} Column information: \n')
    Dataset.info()
    print('\n')
    print(f'{Dataset_Name} Missing information: \n',Dataset.isnull().sum(), '\n')
    print(f'{Dataset_Name} Duplicate information: \n',Dataset.duplicated().sum(), '\n')
    print(f'{Dataset_Name} Statistical Summary: \n',Dataset.describe(), '\n')
    print(f'End of {Dataset_Name} sanity check \n')

# %%
#Sanity Check for Bid Red
sanity_check(bid_red, 'Bid Red')
# Out:
# Bid Red Sanity Check:
#
#
#     deal_id       month    bid_request        bids
# 0  Deal_149  01/01/2024         160.00           0
# 1  Deal_149  01/05/2024         160.00  2320359348
# 2  Deal_222  01/02/2024 45169671695.00  6431140982
# 3  Deal_222  01/04/2024 74806028011.00  5821454587
# 4  Deal_222  01/09/2024 68845194016.00           0
# Bid Red Rows and Columns:
#  (1132, 4)
#
# Bid Red Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132 entries, 0 to 1131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      1132 non-null   object
#  1   month        1132 non-null   object
#  2   bid_request  1132 non-null   float64
#  3   bids         1132 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 35.5+ KB
#
#
# Bid Red Missing information:
#  deal_id        0
# month          0
# bid_request    0
# bids           0
# dtype: int64
#
# Bid Red Duplicate information:
#  0
#
# Bid Red Statistical Summary:
#            bid_request           bids
# count         1132.00        1132.00
# mean   95372278085.95  5870149054.87
# std   110894431149.78  7107228982.18
# min            160.00           0.00
# 25%            160.00           0.00
# 50%    55682516225.50  3144363396.00
# 75%   163250000000.00 10365478039.25
# max   557000000000.00 44441690515.00
#
# End of Bid Red sanity check

# %%
#Bid bld blue Sanity Check
sanity_check(bid_blue, 'Bid Blue')
# Out:
# Bid Blue Sanity Check:
#
#
#     deal_id       month     bid_request         bids
# 0  Deal_102  01/01/2024          160.00  11418560961
# 1  Deal_102  01/02/2024          160.00   4218636088
# 2  Deal_102  01/04/2024 287000000000.00   7902414504
# 3  Deal_102  01/05/2024          160.00  30286237905
# 4  Deal_102  01/06/2024 201000000000.00            0
# Bid Blue Rows and Columns:
#  (748, 4)
#
# Bid Blue Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      748 non-null    object
#  1   month        748 non-null    object
#  2   bid_request  748 non-null    float64
#  3   bids         748 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.5+ KB
#
#
# Bid Blue Missing information:
#  deal_id        0
# month          0
# bid_request    0
# bids           0
# dtype: int64
#
# Bid Blue Duplicate information:
#  0
#
# Bid Blue Statistical Summary:
#            bid_request           bids
# count          748.00         748.00
# mean   83372563851.83  6156973885.02
# std   104246600250.14  7556392469.17
# min            160.00           0.00
# 25%            160.00           0.00
# 50%    34921890202.00  3133102090.00
# 75%   143500000000.00 10501080076.25
# max   476000000000.00 37064307785.00
#
# End of Bid Blue sanity check

# %%
#Deal Performance sanity check
sanity_check(Deal_Performance, 'Deal Performance')
# Out:
# Deal Performance Sanity Check:
#
#
#     deal_id          deal_name      month segment_type      ssp    advertiser            vertical office         tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes  clicks  media_margin
# 0  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42
# 1  Deal_102  Deal_102_Campaign 2024-02-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC       6.00       153.74      110.30         43.45         9900         12508.00   18.38         28.26
# 2  Deal_102  Deal_102_Campaign 2024-04-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.10       142.57      101.25         41.32        21614             1.00   21.61         28.98
# 3  Deal_102  Deal_102_Campaign 2024-05-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC       4.00       164.75       97.48         67.26        81433             1.00   24.37         40.83
# 4  Deal_102  Deal_102_Campaign 2024-06-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.10       172.89      101.11         71.78        89362         41537.00   89.36         41.52
# Deal Performance Rows and Columns:
#  (1980, 19)
#
# Deal Performance Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   deal_id          1980 non-null   object
#  1   deal_name        1980 non-null   object
#  2   month            1980 non-null   datetime64[ns]
#  3   segment_type     1980 non-null   object
#  4   ssp              1980 non-null   object
#  5   advertiser       1980 non-null   object
#  6   vertical         1980 non-null   object
#  7   office           1980 non-null   object
#  8   tier             1980 non-null   object
#  9   media_type       1980 non-null   object
#  10  kpi              1980 non-null   object
#  11  kpi_value        1980 non-null   float64
#  12  gross_spend      1980 non-null   float64
#  13  media_cost       1980 non-null   float64
#  14  data_revenue     1980 non-null   float64
#  15  impressions      1980 non-null   int64
#  16  video_completes  1980 non-null   float64
#  17  clicks           1980 non-null   float64
#  18  media_margin     1980 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(10)
# memory usage: 294.0+ KB
#
#
# Deal Performance Missing information:
#  deal_id            0
# deal_name          0
# month              0
# segment_type       0
# ssp                0
# advertiser         0
# vertical           0
# office             0
# tier               0
# media_type         0
# kpi                0
# kpi_value          0
# gross_spend        0
# media_cost         0
# data_revenue       0
# impressions        0
# video_completes    0
# clicks             0
# media_margin       0
# dtype: int64
#
# Deal Performance Duplicate information:
#  0
#
# Deal Performance Statistical Summary:
#                                 month  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes  clicks  media_margin
# count                           1980    1980.00      1980.00     1980.00       1980.00      1980.00          1980.00 1980.00       1980.00
# mean   2024-07-15 23:54:10.909090816      23.92        97.70       48.88         48.82     48248.58         23302.17   55.91         47.36
# min              2024-01-01 00:00:00       0.10         0.69        0.35          0.15         1.00             0.90    0.01         17.58
# 25%              2024-04-01 00:00:00       0.35         1.16        0.65          0.53         1.00             1.00    0.15         40.00
# 50%              2024-08-01 00:00:00       4.00         4.95        2.47          2.48     20447.00          7628.00   15.84         48.08
# 75%              2024-11-01 00:00:00      60.00       136.21       66.65         66.26     85027.50         40334.00   94.60         54.57
# max              2025-02-01 00:00:00      90.00      1951.71     1330.40        728.81    350304.00        210182.40  399.00         65.00
# std                              NaN      34.79       180.57       98.84         89.84     60927.91         31290.76   74.27         10.55
#
# End of Deal Performance sanity check

# %% [markdown]
# The Datasets have no missing data. However, the date column datatype is an object and must be changed to a much more appropriate datatype.

# %%
#Converting both to datetime datatypes
bid_red['month'] = pd.to_datetime(bid_red['month'])
bid_blue['month'] = pd.to_datetime(bid_blue['month'])

#Checking that datatype change has taken place
bid_blue.info()
print('\n')
bid_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      748 non-null    object
#  1   month        748 non-null    datetime64[ns]
#  2   bid_request  748 non-null    float64
#  3   bids         748 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 23.5+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132 entries, 0 to 1131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      1132 non-null   object
#  1   month        1132 non-null   datetime64[ns]
#  2   bid_request  1132 non-null   float64
#  3   bids         1132 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 35.5+ KB

# %% [markdown]
# Now we Concatenate the bidding datasets to develop a bigger picture of the bidding process.

# %%
combined_bid = pd.concat([bid_blue, bid_red])

# %%
#Sanity Check on the Concatenated Dataset
sanity_check(combined_bid, 'Combined Bid')
# Out:
# Combined Bid Sanity Check:
#
#
#     deal_id      month     bid_request         bids
# 0  Deal_102 2024-01-01          160.00  11418560961
# 1  Deal_102 2024-01-02          160.00   4218636088
# 2  Deal_102 2024-01-04 287000000000.00   7902414504
# 3  Deal_102 2024-01-05          160.00  30286237905
# 4  Deal_102 2024-01-06 201000000000.00            0
# Combined Bid Rows and Columns:
#  (1880, 4)
#
# Combined Bid Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1880 entries, 0 to 1131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   deal_id      1880 non-null   object
#  1   month        1880 non-null   datetime64[ns]
#  2   bid_request  1880 non-null   float64
#  3   bids         1880 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 73.4+ KB
#
#
# Combined Bid Missing information:
#  deal_id        0
# month          0
# bid_request    0
# bids           0
# dtype: int64
#
# Combined Bid Duplicate information:
#  0
#
# Combined Bid Statistical Summary:
#                                 month     bid_request           bids
# count                           1880         1880.00        1880.00
# mean   2024-02-22 22:56:25.531914752  90597923699.18  5984268721.33
# min              2024-01-01 00:00:00          160.00           0.00
# 25%              2024-01-04 00:00:00          160.00           0.00
# 50%              2024-01-07 00:00:00  48618907570.50  3133102090.00
# 75%              2024-01-11 00:00:00 157000000000.00 10454115784.50
# max              2025-01-02 00:00:00 557000000000.00 44441690515.00
# std                              NaN 108429505967.05  7288618647.03
#
# End of Combined Bid sanity check

# %% [markdown]
# Exploring the Deal Performance Dataset to see opprtunities for Data manipulation and wrangling

# %%
Deal_Performance.head(20)
# Out:
#      deal_id          deal_name      month segment_type      ssp    advertiser            vertical     office                     tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes  clicks  media_margin
# 0   Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42
# 1   Deal_102  Deal_102_Campaign 2024-02-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CPC       6.00       153.74      110.30         43.45         9900         12508.00   18.38         28.26
# 2   Deal_102  Deal_102_Campaign 2024-04-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.10       142.57      101.25         41.32        21614             1.00   21.61         28.98
# 3   Deal_102  Deal_102_Campaign 2024-05-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CPC       4.00       164.75       97.48         67.26        81433             1.00   24.37         40.83
# 4   Deal_102  Deal_102_Campaign 2024-06-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.10       172.89      101.11         71.78        89362         41537.00   89.36         41.52
# 5   Deal_102  Deal_102_Campaign 2024-08-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CPC       4.00       162.35      104.80         57.55            1        118455.00   26.20         35.45
# 6   Deal_102  Deal_102_Campaign 2024-10-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.10       143.37      111.40         31.97        20190             1.00   20.19         22.30
# 7   Deal_102  Deal_102_Campaign 2024-11-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CPC       6.00       165.59      110.56         55.03        78846         19981.00   18.43         33.23
# 8   Deal_102  Deal_102_Campaign 2024-12-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.10       151.64       95.11         56.54        27720             1.00   27.72         37.28
# 9   Deal_149  Deal_149_Campaign 2024-01-01       Cookie   REDSSP  Advertiser_2  Law and Government         UK  Below Minimum Threshold    Display  CTR       0.50         4.64        3.33          1.31            1         25265.00    0.01         28.16
# 10  Deal_149  Deal_149_Campaign 2024-05-01       Cookie   REDSSP  Advertiser_2  Law and Government         UK  Below Minimum Threshold    Display  CPC       4.00         4.76        3.27          1.49            1             1.00    0.82         31.28
# 11  Deal_191  Deal_191_Campaign 2024-01-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CTR       0.10         3.35        1.76          1.59        73641        102567.00   73.64         47.53
# 12  Deal_191  Deal_191_Campaign 2024-10-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CPC       4.00         3.48        1.83          1.66       192720         13948.00    0.46         47.61
# 13  Deal_191  Deal_191_Campaign 2024-12-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CTR       0.50         3.18        1.65          1.53            1             1.00    0.01         48.24
# 14  Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34
# 15  Deal_222  Deal_222_Campaign 2024-04-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CPC       4.00         1.82        0.90          0.92            1         36861.00    0.22         50.57
# 16  Deal_222  Deal_222_Campaign 2024-09-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.27         1.73        0.85          0.88        54727         30902.00  147.76         50.66
# 17  Deal_222  Deal_222_Campaign 2024-10-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CPC       4.00         1.54        0.89          0.66       118088         52162.00    0.22         42.62
# 18  Deal_222  Deal_222_Campaign 2024-11-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.72        0.78          0.93            1             1.00    0.01         54.32
# 19  Deal_222  Deal_222_Campaign 2025-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CPC       4.00         1.61        0.86          0.75        12806             1.00    0.21         46.70

# %% [markdown]
# Given that KPIs and their respecive values could form an integral part of the necessary analysis. The respective KPIs within the dataset should become variables alongside the existing variables.

# %%
#First we created a pivot based on the advertiser and the various KPIs
pivoted = Deal_Performance.pivot_table(index = 'advertiser', columns = 'kpi', values = 'kpi_value').reset_index()

#Then we Merge this Deal Performance dataframe
Deal_Performance = pd.merge(Deal_Performance, pivoted, how= 'inner', on= 'advertiser')

# %%
#The First five rows of the new dataframe
Deal_Performance.head()
# Out:
#     deal_id          deal_name      month segment_type      ssp    advertiser            vertical office         tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes  clicks  media_margin  CPC  CTR  VTR
# 0  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12  NaN
# 1  Deal_102  Deal_102_Campaign 2024-02-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC       6.00       153.74      110.30         43.45         9900         12508.00   18.38         28.26 5.00 0.12  NaN
# 2  Deal_102  Deal_102_Campaign 2024-04-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.10       142.57      101.25         41.32        21614             1.00   21.61         28.98 5.00 0.12  NaN
# 3  Deal_102  Deal_102_Campaign 2024-05-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CPC       4.00       164.75       97.48         67.26        81433             1.00   24.37         40.83 5.00 0.12  NaN
# 4  Deal_102  Deal_102_Campaign 2024-06-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.10       172.89      101.11         71.78        89362         41537.00   89.36         41.52 5.00 0.12  NaN

# %% [markdown]
# Above we can see that the dataframe has successfully incorporated the KPIs as part of the variables. Now we can combine both datasets

# %%
Data = pd.merge(Deal_Performance, combined_bid, how= 'inner', on= 'deal_id')

# %%
#First Five Rows of the new dataset
Data.head(181)
# Out:
#       deal_id          deal_name    month_x segment_type      ssp    advertiser            vertical     office                     tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes  clicks  media_margin  CPC  CTR   VTR    month_y     bid_request         bids
# 0    Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12   NaN 2024-01-01          160.00  11418560961
# 1    Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12   NaN 2024-01-02          160.00   4218636088
# 2    Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12   NaN 2024-01-04 287000000000.00   7902414504
# 3    Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12   NaN 2024-01-05          160.00  30286237905
# 4    Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education         UK              Growth Tier    Display  CTR       0
# 89   Deal_191  Deal_191_Campaign 2024-10-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CPC       4.00         3.48        1.83          1.66       192720         13948.00    0.46         47.61 4.00 0.30   NaN 2024-01-10 253000000000.00  17670097169
# 90   Deal_191  Deal_191_Campaign 2024-10-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CPC       4.00         3.48        1.83          1.66       192720         13948.00    0.46         47.61 4.00 0.30   NaN 2024-01-12 104000000000.00   2668731247
# 91   Deal_191  Deal_191_Campaign 2024-12-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CTR       0.50         3.18        1.65          1.53            1             1.00    0.01         48.24 4.00 0.30   NaN 2024-01-01          160.00            0
# 92   Deal_191  Deal_191_Campaign 2024-12-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CTR       0.50         3.18        1.65          1.53            1             1.00    0.01         48.24 4.00 0.30   NaN 2024-01-10 253000000000.00  17670097169
# 93   Deal_191  Deal_191_Campaign 2024-12-01       Cookie  BLUESSP  Advertiser_3             Charity  Australia  Below Minimum Threshold    Display  CTR       0.50         3.18        1.65          1.53            1             1.00    0.01         48.24 4.00 0.30   NaN 2024-01-12 104000000000.00   2668731247
# 94   Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34 4.20 0.42 80.49 2024-01-02  45169671695.00   6431140982
# 95   Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34 4.20 0.42 80.49 2024-01-04  74806028011.00   5821454587
# 96   Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34 4.20 0.42 80.49 2024-01-09  68845194016.00            0
# 97   Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34 4.20 0.42 80.49 2024-01-10 168000000000.00   9339744976
# 98   Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34 4.20 0.42 80.49 2024-01-11          160.00            0
# 99   Deal_222  Deal_222_Campaign 2024-02-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CTR       0.50         1.83        0.78          1.05            1         91465.00    0.01         57.34 4.20 0.42 80.49 2025-01-02          160.00   9582431683
# 100  Deal_222  Deal_222_Campaign 2024-04-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CPC       4.00         1.82        0.90          0.92            1         36861.00    0.22         50.57 4.20 0.42 80.49 2024-01-02  45169671695.00   6431140982
# 101  Deal_222  Deal_222_Campaign 2024-04-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CPC       4.00         1.82        0.90          0.92            1         36861.00    0.22         50.57 4.20 0.42 80.49 2024-01-04  74806028011.00   5821454587
# 102  Deal_222  Deal_222_Campaign 2024-04-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  CPC       4.00         1.82        0.90          0.92            1         36861.00    0.22         50.57 4.20 0.42 80.49 2024-01-09  68845194016.00            0
# 103  Deal_222  Deal_222_Campaign 2024-04-01       Cookie   REDSSP  Advertiser_4   Style and Fashion         UK              Growth Tier    Display  
01   Cookieless   REDSSP  Advertiser_4          Automotive         UK              Growth Tier    Display  CTR       0.50         0.91        0.51          0.40            1             1.00    0.01         44.07 4.20 0.42 80.49 2024-01-05 116000000000.00  12074219802
# 178  Deal_198  Deal_198_Campaign 2024-04-01   Cookieless   REDSSP  Advertiser_4          Automotive         UK              Growth Tier    Display  CTR       0.50         0.91        0.51          0.40            1             1.00    0.01         44.07 4.20 0.42 80.49 2024-01-06  40167800643.00    579138863
# 179  Deal_198  Deal_198_Campaign 2024-04-01   Cookieless   REDSSP  Advertiser_4          Automotive         UK              Growth Tier    Display  CTR       0.50         0.91        0.51          0.40            1             1.00    0.01         44.07 4.20 0.42 80.49 2024-01-08 335000000000.00            0
# 180  Deal_198  Deal_198_Campaign 2024-04-01   Cookieless   REDSSP  Advertiser_4          Automotive         UK              Growth Tier    Display  CTR       0.50         0.91        0.51          0.40            1             1.00    0.01         44.07 4.20 0.42 80.49 2024-01-10   2887756567.00  11747793929

# %%
#Remove the extra date column
Data = Data.drop('month_y', axis = 1)

# %%
#Renaming the existing month column
Data = Data.rename(columns = {'month_x':'Date'})

# %%
#Sanity check for combined Dataset
sanity_check(Data, 'Combined Dataset')
# Out:
# Combined Dataset Sanity Check:
#
#
#     deal_id          deal_name       Date segment_type      ssp    advertiser            vertical office         tier media_type  kpi  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes  clicks  media_margin  CPC  CTR  VTR     bid_request         bids
# 0  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12  NaN          160.00  11418560961
# 1  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12  NaN          160.00   4218636088
# 2  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12  NaN 287000000000.00   7902414504
# 3  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12  NaN          160.00  30286237905
# 4  Deal_102  Deal_102_Campaign 2024-01-01   Cookieless  BLUESSP  Advertiser_1  Jobs and Education     UK  Growth Tier    Display  CTR       0.19       154.76      109.24         45.52        66474         50812.00  126.30         29.42 5.00 0.12  NaN 201000000000.00            0
# Combined Dataset Rows and Columns:
#  (15931, 24)
#
# Combined Dataset Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   deal_id          15931 non-null  object
#  1   deal_name        15931 non-null  object
#  2   Date             15931 non-null  datetime64[ns]
#  3   segment_type     15931 non-null  object
#  4   ssp              15931 non-null  object
#  5   advertiser       15931 non-null  object
#  6   vertical         15931 non-null  object
#  7   office           15931 non-null  object
#  8   tier             15931 non-null  object
#  9   media_type       15931 non-null  object
#  10  kpi              15931 non-null  object
#  11  kpi_value        15931 non-null  float64
#  12  gross_spend      15931 non-null  float64
#  13  media_cost       15931 non-null  float64
#  14  data_revenue     15931 non-null  float64
#  15  impressions      15931 non-null  int64
#  16  video_completes  15931 non-null  float64
#  17  clicks           15931 non-null  float64
#  18  media_margin     15931 non-null  float64
#  19  CPC              11155 non-null  float64
#  20  CTR              15723 non-null  float64
#  21  VTR              12759 non-null  float64
#  22  bid_request      15931 non-null  float64
#  23  bids             15931 non-null  int64
# dtypes: datetime64[ns](1), float64(11), int64(2), object(10)
# memory usage: 2.9+ MB
#
#
# Combined Dataset Missing information:
#  deal_id               0
# deal_name             0
# Date                  0
# segment_type          0
# ssp                   0
# advertiser            0
# vertical              0
# office                0
# tier                  0
# media_type            0
# kpi                   0
# kpi_value             0
# gross_spend           0
# media_cost            0
# data_revenue          0
# impressions           0
# video_completes       0
# clicks                0
# media_margin          0
# CPC                4776
# CTR                 208
# VTR                3172
# bid_request           0
# bids                  0
# dtype: int64
#
# Combined Dataset Duplicate information:
#  870
#
# Combined Dataset Statistical Summary:
#                                  Date  kpi_value  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin      CPC      CTR      VTR     bid_request           bids
# count                          15931   15931.00     15931.00    15931.00      15931.00     15931.00         15931.00 15931.00      15931.00 11155.00 15723.00 12759.00        15931.00       15931.00
# mean   2024-07-18 15:01:22.028749056      23.64        77.86       37.77         40.09     48284.80         23401.25    56.10         47.56     4.37     0.31    74.27  92012202634.35  6017993065.94
# min              2024-01-01 00:00:00       0.10         0.69        0.35          0.15         1.00             0.90     0.01         17.58     4.00     0.10    60.00          160.00           0.00
# 25%              2024-04-01 00:00:00       0.32         0.99        0.56          0.46         1.00             1.00     0.14         40.43     4.00     0.27    70.00          160.00           0.00
# 50%              2024-08-01 00:00:00       4.00         4.74        2.26          2.42     21088.00          7815.00    15.01         48.19     4.00     0.30    75.00  52461854203.00  3236453327.00
# 75%              2024-11-01 00:00:00      60.00       125.64       59.52         58.75     85287.00         40633.00    95.04         54.88     4.60     0.35    78.00 158000000000.00 10557252821.00
# max              2025-02-01 00:00:00      90.00      1951.71     1330.40        728.81    350304.00        210182.40   399.00         65.00     6.00     0.50    90.00 557000000000.00 44441690515.00
# std                              NaN      34.61       134.26       69.28         70.95     60635.94         31109.91    74.72         10.53     0.49     0.08     6.56 108743103584.75  7237083835.15
#
# End of Combined Dataset sanity check

# %% [markdown]
# Most of the data is present. However, some advertisers do not use certain KPIs so the KPI categories are deemed null. We will replace these null value with the actual values of zero. We will also be dropping the duplicates for the purposes of data cleanliness

# %%
Data.fillna(0, inplace= True)
Data.drop_duplicates(inplace= True)

# %% [markdown]
# **Data Aggregation**
#
# Now we have successfully combined and cleaned the three datasets. It is time to construct an aggregated dataset that summarises the data of the various advertisers to conduct analysis and further investigations.

# %%
#Firstly we will create a calculated column to describe the bid success rate
Data['bid_rate'] = Data['bids']/Data['bid_request']
# Now we create an aggregated dataset
Data_Agg = Data.groupby(['advertiser']).agg({'segment_type': pd.Series.mode, 'vertical': pd.Series.mode, 'tier': pd.Series.mode, 'media_type': pd.Series.mode, 'Date':'max', 'gross_spend': 'median', 'media_cost': 'median',
                                           'data_revenue': 'median', 'impressions': 'median', 'video_completes': 'median', 'clicks': 'sum', 'media_margin': 'median', 'CPC': 'mean', 'CTR':'mean', 'VTR':'mean', 'bid_request': 'sum', 'bids': 'sum', 'bid_rate': 'mean'})

for col in ['segment_type', 'vertical', 'tier', 'media_type']:
    Data_Agg[col] = Data_Agg[col].astype(str) #Ensures that certain aggregated column have the correct datatype
Data_Agg.reset_index(inplace= True)

# %%
#First rows of new dataset
Data_Agg.head()
# Out:
#        advertiser segment_type            vertical                     tier media_type       Date  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin  CPC  CTR   VTR       bid_request           bids    bid_rate
# 0    Advertiser_1   Cookieless  Jobs and Education              Growth Tier    Display 2024-12-01       154.76      104.80         55.03     27720.00         12508.00  2980.54         33.23 5.00 0.12  0.00  6022480319964.00   612203155209 35877683.59
# 1   Advertiser_10   Cookieless            Gambling  Below Minimum Threshold      Video 2025-02-01         2.10        1.07          1.15     31247.00          5075.40 19757.19         46.36 4.00 0.26 77.99 22720722645968.00  1333345362683  6033153.02
# 2  Advertiser_100   Cookieless              Travel                 Mid-Tier      Video 2025-02-01        37.47       14.83         21.50     71807.00         57760.00 11093.75         57.36 4.00 0.30 70.77 24843172026557.00  2351876589913 23507249.16
# 3  Advertiser_101   Cookieless             Alcohol              White Glove      Video 2025-02-01         0.76        0.38          0.40         1.00             1.00  7268.10         51.03 4.00 0.31 75.00 16386449369052.00  1516421046670 16684643.70
# 4  Advertiser_102       Cookie   Style and Fashion  Below Minimum Threshold      Video 2024-12-01         1.67        0.96          0.70     30656.00         18884.10  2532.87         41.95 0.00 0.36 74.13  2616000002880.00   185088475542 15781298.47

# %%
#Sanity Check
sanity_check(Data_Agg, 'Aggregated Dataset')
# Out:
# Aggregated Dataset Sanity Check:
#
#
#        advertiser segment_type            vertical                     tier media_type       Date  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin  CPC  CTR   VTR       bid_request           bids    bid_rate
# 0    Advertiser_1   Cookieless  Jobs and Education              Growth Tier    Display 2024-12-01       154.76      104.80         55.03     27720.00         12508.00  2980.54         33.23 5.00 0.12  0.00  6022480319964.00   612203155209 35877683.59
# 1   Advertiser_10   Cookieless            Gambling  Below Minimum Threshold      Video 2025-02-01         2.10        1.07          1.15     31247.00          5075.40 19757.19         46.36 4.00 0.26 77.99 22720722645968.00  1333345362683  6033153.02
# 2  Advertiser_100   Cookieless              Travel                 Mid-Tier      Video 2025-02-01        37.47       14.83         21.50     71807.00         57760.00 11093.75         57.36 4.00 0.30 70.77 24843172026557.00  2351876589913 23507249.16
# 3  Advertiser_101   Cookieless             Alcohol              White Glove      Video 2025-02-01         0.76        0.38          0.40         1.00             1.00  7268.10         51.03 4.00 0.31 75.00 16386449369052.00  1516421046670 16684643.70
# 4  Advertiser_102       Cookie   Style and Fashion  Below Minimum Threshold      Video 2024-12-01         1.67        0.96          0.70     30656.00         18884.10  2532.87         41.95 0.00 0.36 74.13  2616000002880.00   185088475542 15781298.47
# Aggregated Dataset Rows and Columns:
#  (181, 19)
#
# Aggregated Dataset Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   advertiser       181 non-null    object
#  1   segment_type     181 non-null    object
#  2   vertical         181 non-null    object
#  3   tier             181 non-null    object
#  4   media_type       181 non-null    object
#  5   Date             181 non-null    datetime64[ns]
#  6   gross_spend      181 non-null    float64
#  7   media_cost       181 non-null    float64
#  8   data_revenue     181 non-null    float64
#  9   impressions      181 non-null    float64
#  10  video_completes  181 non-null    float64
#  11  clicks           181 non-null    float64
#  12  media_margin     181 non-null    float64
#  13  CPC              181 non-null    float64
#  14  CTR              181 non-null    float64
#  15  VTR              181 non-null    float64
#  16  bid_request      181 non-null    float64
#  17  bids             181 non-null    int64
#  18  bid_rate         181 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(5)
# memory usage: 27.0+ KB
#
#
# Aggregated Dataset Missing information:
#  advertiser         0
# segment_type       0
# vertical           0
# tier               0
# media_type         0
# Date               0
# gross_spend        0
# media_cost         0
# data_revenue       0
# impressions        0
# video_completes    0
# clicks             0
# media_margin       0
# CPC                0
# CTR                0
# VTR                0
# bid_request        0
# bids               0
# bid_rate           0
# dtype: int64
#
# Aggregated Dataset Duplicate information:
#  0
#
# Aggregated Dataset Statistical Summary:
#                                  Date  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin    CPC    CTR    VTR       bid_request             bids    bid_rate
# count                            181       181.00      181.00        181.00       181.00           181.00   181.00        181.00 181.00 181.00 181.00            181.00           181.00      181.00
# mean   2024-10-28 18:01:59.337016576       139.14       73.96         65.08     31786.25         12582.97  4652.27         46.44   2.39   0.30  49.64  8098598895185.59  529683135543.86 14023588.50
# min              2024-01-01 00:00:00         0.75        0.38          0.27         1.00             0.90     0.01         20.69   0.00   0.00   0.00            160.00             0.00        0.00
# 25%              2024-08-01 00:00:00         1.51        0.84          0.67         1.00             1.00   707.81         39.87   0.00   0.23   0.00  1074047977012.00   79476587590.00  1158957.99
# 50%              2025-01-01 00:00:00         6.66        3.38          2.66     22478.00          6844.00  2506.68         47.68   4.00   0.30  70.00  4724652551488.00  265502920800.00 11734867.85
# 75%              2025-02-01 00:00:00       160.85       78.33         73.95     49690.00         19675.80  7179.89         51.53   4.00   0.37  76.67 13562499228630.00  849481720839.00 20631301.92
# max              2025-02-01 00:00:00      1951.71     1330.40        623.19    227636.50        123502.80 28562.38         65.00   6.00   0.50  90.00 40168696981684.00 2538746594866.00 82157647.42
# std                              NaN       269.73      158.44        121.77     35747.65         16746.36  5350.02          9.64   2.25   0.13  36.18  8823347868417.22  595180324781.13 13945461.65
#
# End of Aggregated Dataset sanity check

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# There is no misssing data.
#
# Now we create a Column to numerically classify churned v unchurned customers.

# %%
#Firstly, we create a variable called current time
current_time = dt.now()

#Then we create a column to stating the difference between today, and the last transaction

Data_Agg['months_since_last_transaction'] = round((current_time - Data_Agg['Date']).dt.days/30, 1)


#Given the business rule that customers with a most recent purchase date of more than 6 months are considered churned.

Data_Agg['churned'] = np.where(Data_Agg['months_since_last_transaction'] > 6, 1, 0)

Data_Agg['churned_category'] = np.where(Data_Agg['months_since_last_transaction'] > 6, 'Churned', 'Active')
Data_Agg['churned'] = Data_Agg['churned'].astype('int')

# %% [markdown]
# Media Margin Classification:
#
# Conducting statistical analysis between Media margin and other variables can be bolstered by classifying media_margin into 4 separate categories

# %%
#Classifying the respective advertisers
Data_Agg['media_margin_category'] = pd.qcut(Data_Agg['media_margin'], q=4, labels=['Low', 'Medium', 'High', 'Very High'])
Data_Agg['media_margin_category']= Data_Agg['media_margin_category'].astype('category')

#Providing an equivalent numerical classification
Data_Agg['media_margin_category_num'] = pd.qcut(Data_Agg['media_margin'], q=4, labels=[1, 2, 3, 4])

# %%
#Final Sanity Check
sanity_check(Data_Agg, 'Aggregated Dataset')
# Out:
# Aggregated Dataset Sanity Check:
#
#
#        advertiser segment_type            vertical                     tier media_type       Date  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin  CPC  CTR   VTR       bid_request           bids    bid_rate  months_since_last_transaction  churned churned_category media_margin_category media_margin_category_num
# 0    Advertiser_1   Cookieless  Jobs and Education              Growth Tier    Display 2024-12-01       154.76      104.80         55.03     27720.00         12508.00  2980.54         33.23 5.00 0.12  0.00  6022480319964.00   612203155209 35877683.59                           3.80        0           Active                   Low                         1
# 1   Advertiser_10   Cookieless            Gambling  Below Minimum Threshold      Video 2025-02-01         2.10        1.07          1.15     31247.00          5075.40 19757.19         46.36 4.00 0.26 77.99 22720722645968.00  1333345362683  6033153.02                           1.70        0           Active                Medium                         2
# 2  Advertiser_100   Cookieless              Travel                 Mid-Tier      Video 2025-02-01        37.47       14.83         21.50     71807.00         57760.00 11093.75         57.36 4.00 0.30 70.77 24843172026557.00  2351876589913 23507249.16                           1.70        0           Active             Very High                         4
# 3  Advertiser_101   Cookieless             Alcohol              White Glove      Video 2025-02-01         0.76        0.38          0.40         1.00             1.00  7268.10         51.03 4.00 0.31 75.00 16386449369052.00  1516421046670 16684643.70                           1.70        0           Active                  High                         3
# 4  Advertiser_102       Cookie   Style and Fashion  Below Minimum Threshold      Video 2024-12-01         1.67        0.96          0.70     30656.00         18884.10  2532.87         41.95 0.00 0.36 74.13  2616000002880.00   185088475542 15781298.47                           3.80        0           Active                Medium                         2
# Aggregated Dataset Rows and Columns:
#  (181, 24)
#
# Aggregated Dataset Column information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   advertiser                     181 non-null    object
#  1   segment_type                   181 non-null    object
#  2   vertical                       181 non-null    object
#  3   tier                           181 non-null    object
#  4   media_type                     181 non-null    object
#  5   Date                           181 non-null    datetime64[ns]
#  6   gross_spend                    181 non-null    float64
#  7   media_cost                     181 non-null    float64
#  8   data_revenue                   181 non-null    float64
#  9   impressions                    181 non-null    float64
#  10  video_completes                181 non-null    float64
#  11  clicks                         181 non-null    float64
#  12  media_margin                   181 non-null    float64
#  13  CPC                            181 non-null    float64
#  14  CTR                            181 non-null    float64
#  15  VTR                            181 non-null    float64
#  16  bid_request                    181 non-null    float64
#  17  bids                           181 non-null    int64
#  18  bid_rate                       181 non-null    float64
#  19  months_since_last_transaction  181 non-null    float64
#  20  churned                        181 non-null    int64
#  21  churned_category               181 non-null    object
#  22  media_margin_category          181 non-null    category
#  23  media_margin_category_num      181 non-null    category
# dtypes: category(2), datetime64[ns](1), float64(13), int64(2), object(6)
# memory usage: 32.0+ KB
#
#
# Aggregated Dataset Missing information:
#  advertiser                       0
# segment_type                     0
# vertical                         0
# tier                             0
# media_type                       0
# Date                             0
# gross_spend                      0
# media_cost                       0
# data_revenue                     0
# impressions                      0
# video_completes                  0
# clicks                           0
# media_margin                     0
# CPC                              0
# CTR                              0
# VTR                              0
# bid_request                      0
# bids                             0
# bid_rate                         0
# months_since_last_transaction    0
# churned                          0
# churned_category                 0
# media_margin_category            0
# media_margin_category_num        0
# dtype: int64
#
# Aggregated Dataset Duplicate information:
#  0
#
# Aggregated Dataset Statistical Summary:
#                                  Date  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin    CPC    CTR    VTR       bid_request             bids    bid_rate  months_since_last_transaction  churned
# count                            181       181.00      181.00        181.00       181.00           181.00   181.00        181.00 181.00 181.00 181.00            181.00           181.00      181.00                         181.00   181.00
# mean   2024-10-28 18:01:59.337016576       139.14       73.96         65.08     31786.25         12582.97  4652.27         46.44   2.39   0.30  49.64  8098598895185.59  529683135543.86 14023588.50                           4.90     0.41
# min              2024-01-01 00:00:00         0.75        0.38          0.27         1.00             0.90     0.01         20.69   0.00   0.00   0.00            160.00             0.00        0.00                           1.70     0.00
# 25%              2024-08-01 00:00:00         1.51        0.84          0.67         1.00             1.00   707.81         39.87   0.00   0.23   0.00  1074047977012.00   79476587590.00  1158957.99                           1.70     0.00
# 50%              2025-01-01 00:00:00         6.66        3.38          2.66     22478.00          6844.00  2506.68         47.68   4.00   0.30  70.00  4724652551488.00  265502920800.00 11734867.85                           2.80     0.00
# 75%              2025-02-01 00:00:00       160.85       78.33         73.95     49690.00         19675.80  7179.89         51.53   4.00   0.37  76.67 13562499228630.00  849481720839.00 20631301.92                           7.90     1.00
# max              2025-02-01 00:00:00      1951.71     1330.40        623.19    227636.50        123502.80 28562.38         65.00   6.00   0.50  90.00 40168696981684.00 2538746594866.00 82157647.42                          15.00     1.00
# std                              NaN       269.73      158.44        121.77     35747.65         16746.36  5350.02          9.64   2.25   0.13  36.18  8823347868417.22  595180324781.13 13945461.65                           3.57     0.49
#
# End of Aggregated Dataset sanity check

# %% [markdown]
# Although there is no missing data. Although CTR and VTR are both rate metrics, the dataset stores them on different scales: CTR as a proportion (0–1) and VTR as a percentage (0–100). For consistency in analysis and modeling, I will align the scales before proceeding.

# %%
Data_Agg['CTR'] = Data_Agg['CTR']*100
Data_Agg.head()
# Out:
#        advertiser segment_type            vertical                     tier media_type       Date  gross_spend  media_cost  data_revenue  impressions  video_completes   clicks  media_margin  CPC   CTR   VTR       bid_request           bids    bid_rate  months_since_last_transaction  churned churned_category media_margin_category media_margin_category_num
# 0    Advertiser_1   Cookieless  Jobs and Education              Growth Tier    Display 2024-12-01       154.76      104.80         55.03     27720.00         12508.00  2980.54         33.23 5.00 11.80  0.00  6022480319964.00   612203155209 35877683.59                           3.80        0           Active                   Low                         1
# 1   Advertiser_10   Cookieless            Gambling  Below Minimum Threshold      Video 2025-02-01         2.10        1.07          1.15     31247.00          5075.40 19757.19         46.36 4.00 25.67 77.99 22720722645968.00  1333345362683  6033153.02                           1.70        0           Active                Medium                         2
# 2  Advertiser_100   Cookieless              Travel                 Mid-Tier      Video 2025-02-01        37.47       14.83         21.50     71807.00         57760.00 11093.75         57.36 4.00 29.53 70.77 24843172026557.00  2351876589913 23507249.16                           1.70        0           Active             Very High                         4
# 3  Advertiser_101   Cookieless             Alcohol              White Glove      Video 2025-02-01         0.76        0.38          0.40         1.00             1.00  7268.10         51.03 4.00 30.83 75.00 16386449369052.00  1516421046670 16684643.70                           1.70        0           Active                  High                         3
# 4  Advertiser_102       Cookie   Style and Fashion  Below Minimum Threshold      Video 2024-12-01         1.67        0.96          0.70     30656.00         18884.10  2532.87         41.95 0.00 35.67 74.13  2616000002880.00   185088475542 15781298.47                           3.80        0           Active                Medium                         2

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# This section will investigate the distribution of the focus variables to make judgement on the appropriate statistical tests and procedures.

# %% [markdown]
# Automating EDA tools

# %%
#Automating Shapiro Wilk Test for normality
def Shapiro_Wilk(dataset, variable, variable_title, alpha = 0.05):
  stat, p = shapiro(dataset[variable])
  print('Statistics=%.3f, p=%.3f' % (stat, p))
  if p > alpha:
    print(f'{variable_title} likely has a normal distribution')
  else:
    print(f'{variable_title} does not have a normal distribution')

# %%
#Automating the creation of Histogram_Boxplot
from scipy.stats import shapiro, probplot
def Histogram_Boxplots(dataset, variable, title, xlabel, Color1, Color2):
  fig, ax = plt.subplots(2, 1, sharex= False)

  sns.histplot(dataset[variable], ax= ax[0], color= Color1, bins = 6, kde= True)
  ax[0].set_title(title, fontsize= 15)
  ax[0].set_xlabel('')

  sns.boxplot(x= dataset[variable], ax= ax[1], color= Color2, showmeans = True)
  ax[1].set_xlabel(xlabel, fontsize= 10)
  plt.show()

#Automating the creation of countplot
def univariate_countplot(dataset, variable, title, xlabel, ylabel, Color1):
  sns.countplot(x= dataset[variable], palette= 'bright')
  plt.title(title, fontsize= 15)
  plt.xlabel(xlabel, fontsize= 10)
  plt.ylabel(ylabel, fontsize= 10)
  plt.show()

#Multivariate Countplot
def multivariate_countplot(dataset, variable1, variable2, title, xlabel, ylabel, Color1):
  sns.countplot(x= dataset[variable1], hue= dataset[variable2], palette= 'bright')
  plt.title(title, fontsize= 15)
  plt.xlabel(xlabel, fontsize= 10)
  plt.ylabel(ylabel, fontsize= 10)
  plt.legend(fontsize = 10, loc = 'upper left')
  plt.show()

#Automate Barplot creation
def barplot(dataset, variable1, variable2, title, xlabel, ylabel):
  sns.barplot(x= dataset[variable1], y= dataset[variable2], palette= 'bright')
  plt.title(title, fontsize= 15)
  plt.xlabel(xlabel, fontsize= 10)
  plt.ylabel(ylabel, fontsize= 10)
  plt.show()

#Automating the creation of correlation plot
def correlation_plot(dataset, title, variable1, variable2, Color):
  sns.regplot(x= dataset[variable1], y= dataset[variable2], color= Color)
  plt.title(title, fontsize= 15)

# %%
#Checking the CTR distribution
Histogram_Boxplots(Data_Agg, 'CTR', 'CTR Distribution', 'CTR', 'blue', 'red')

# %% [markdown]
# The distribution is slightly right-skewed, with most CTR values concentrated between 20% and 40%.
#
# The mean (green triangle) and median (central line) are close, indicating mild skewness.
#
# There is a sole CTR outlier near 0, as shown in the boxplot.
#
# The CTR range spans from around 0 to 50%, with a relatively balanced spread.
#
# Overall, the CTRs are somewhat normally distributed with a moderate tail on the lower end.
#
# However, we will verify with a Shapiro Wilk Test.

# %%
#Making sure distribution is normal
Shapiro_Wilk(Data_Agg, 'CTR', 'Click Through Rate')
# Out:
# Statistics=0.946, p=0.000
# Click Through Rate does not have a normal distribution

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.histplot(Data_Agg['CTR'], kde=True)
plt.title('Histogram of CTR')

plt.subplot(1, 2, 2)
probplot(Data_Agg['CTR'], plot=plt)
plt.title('Q-Q Plot of CTR')

plt.tight_layout()
plt.show()

# Shapiro-Wilk test
Shapiro_Wilk(Data_Agg, 'CTR', 'Click Through Rate')
# Out:
# Statistics=0.946, p=0.000
# Click Through Rate does not have a normal distribution

# %% [markdown]
# The CTR data isn’t normally distributed — the histogram shows right skew, and the Q-Q plot deviates from the diagonal, especially in the tails. This suggests needing to use non-parametric methods for analysis.

# %%
#VTR Distribution
Histogram_Boxplots(Data_Agg, 'VTR', 'VTR Distribution', 'VTR', 'blue', 'red')

# %% [markdown]
# The bimodal distribution in VTR arises because:
#
# Some advertisers don't use VTR at all, resulting in very low (~0%) rates.
#
# Others actively optimize for VTR, producing high values (70–90%).
#
# The gap in the middle (20–60%) suggests that advertisers either fully engage with VTR metrics or not at all — there's little in-between.
#
# This reinforces the idea of distinct advertiser behaviors or strategies in the dataset.
#
# Given the other than normal distribution. Non-parametric tests are appropriate here.

# %%
#Media Margin Distribution
Histogram_Boxplots(Data_Agg, 'media_margin', 'Media Margin Distribution', 'Media Margin', 'blue', 'red')

# %% [markdown]
# Similar to CTR, there is a semblance of normality within the distribution. We will clarify with a test for non-normality.

# %%
#Testing for non normality
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.histplot(Data_Agg['media_margin'], kde=True)
plt.title('Histogram of Media Margin')

plt.subplot(1, 2, 2)
probplot(Data_Agg['media_margin'], plot=plt)
plt.title('Q-Q Plot of Media Margin')

plt.tight_layout()
plt.show()

# Shapiro-Wilk test
Shapiro_Wilk(Data_Agg, 'media_margin', 'media_margin')
# Out:
# Statistics=0.979, p=0.009
# media_margin does not have a normal distribution

# %%
#Checking Cost Per Click for Normality

Histogram_Boxplots(Data_Agg, 'CPC', 'CPC Distribution', 'CPC', 'blue', 'red')

# %% [markdown]
# The distribution is bimodal — there are two distinct peaks: one between 0 and 1 and one between 4 and 5.
#
# This shape violates the assumption of unimodality and symmetry expected in a normal distribution.
#
# There is also a large dip between 2 and 3, which further stresses that this is not normally distributed.

# %% [markdown]
# Given the non normality of our metrics. We will be using non parametric tests for the purposes of statistical testing.

# %% [markdown]
# # Statistical Testing

# %% [markdown]
# In this section, we will be conducting statistical tests to assess the strength of the relationship between Media Margin and various performance metrics such as CTR and VTR.
#
# We will also assess the impact of the Media Margin Rate on Churn.

# %%
from scipy.stats import spearmanr
from scipy.stats import chi2_contingency

# %%
#Automating Statistical Tests
def Spearman_Correlation(dataset, variable1, variable2, alpha = 0.05):
  corr_coef, p_value = spearmanr(dataset[variable1], dataset[variable2])
  print(f"Spearman's correlation coefficient: {corr_coef}")
  print(f"p-value: {p_value}")

  if p_value < alpha:
    print(f"There is a statistically significant correlation between {variable1} and {variable2}")
  else:
    print(f"There is no statistically significant correlation between {variable1} and {variable2}")


def Chi_Squared(dataset, variable1, variable2, alpha = 0.05):
  table = pd.crosstab(index = dataset[variable1], columns = dataset[variable2])
  chi2, p_value, dof, expected = chi2_contingency(table)
  print(f"Chi-squared statistic: {chi2}")
  print(f"p-value: {p_value}")

  if p_value < alpha:
    print(f"There is a statistically significant correlation between {variable1} and {variable2}")
  else:
    print(f"There is no statistically significant correlation between {variable1} and {variable2}")

# %% [markdown]
# Assessing the relationship between Media Margin and Click Through Rate

# %%
#Assessing the relationship between Media Margin Rate and CTR
correlation_plot(Data_Agg, 'Correlation between Media Margin and CTR', 'media_margin', 'CTR', 'blue')

# %%
Spearman_Correlation(Data_Agg, 'media_margin', 'CTR')
# Out:
# Spearman's correlation coefficient: -0.014495938123649153
# p-value: 0.846424937497297
# There is no statistically significant correlation between media_margin and CTR

# %% [markdown]
# The extremely low correlation coefficient -0.015 and high p value 0.84 means that there is a statistically insignificant correlation between Media Margin rates and CTR.

# %% [markdown]
# Assessing the relationship between Media Margin Rates and Viewed Through Rate

# %%
correlation_plot(Data_Agg, 'Correlation between Media Margin and VTR', 'media_margin', 'VTR', 'blue')

# %%
Spearman_Correlation(Data_Agg, 'media_margin', 'VTR')
# Out:
# Spearman's correlation coefficient: 0.1121971280956168
# p-value: 0.13264514897162952
# There is no statistically significant correlation between media_margin and VTR

# %% [markdown]
# Once again, the relationship betweem Media Margin and Viewed Through Rate is not only weak. But statistically insignificant.
#
# The P value means means that we fail to reject the null hypothesis that margin rate has no effect on Viewed Through Rates.

# %% [markdown]
# Assessing the relationship between Media Margin Cost and Cost Per Click

# %%
correlation_plot(Data_Agg, 'Correlation between Media Margin and CPC', 'media_margin', 'CPC', 'blue')

# %%
Spearman_Correlation(Data_Agg, 'media_margin', 'CPC')
# Out:
# Spearman's correlation coefficient: -0.04116275368386369
# p-value: 0.5821926500939569
# There is no statistically significant correlation between media_margin and CPC

# %% [markdown]
# There is no meaningful relationship between Media Margin and CPC in the data. The correlation is very weak and not statistically significant, indicating that changes in CPC do not appear to impact Media Margin.

# %% [markdown]
# Assessing the relationshio between Media Margin Rates and Churn.

# %%
Chi_Squared(Data_Agg, 'media_margin_category', 'churned')
# Out:
# Chi-squared statistic: 8.446812436166361
# p-value: 0.037625971847928937
# There is a statistically significant correlation between media_margin_category and churned

# %% [markdown]
# interestingly again, across categories,  Media Margin has no statisticlly effect on Churn. Given the p value, 0.04, is lower than alpha. We reject the null hypothesis that media margin rates categories have no effect on churn.

# %% [markdown]
# A Summary view of the statistically insignificant relationship between Media Margin and Churn.

# %%
plt.subplot(2, 2, 1)
plt.suptitle('Media Margin Does not Drive Performance or Churn Differences')
sns.barplot(Data_Agg, x= 'media_margin_category', y= 'CTR', palette= 'bright')
plt.title('', fontsize= 15)
plt.xlabel('Media Margin Category', fontsize= 10)
plt.subplot(2, 2, 2
            )
sns.barplot(Data_Agg, x = 'media_margin_category', y= 'VTR', palette ='bright')
plt.title('', fontsize= 15)

plt.xlabel('Media Margin Category', fontsize= 10)
plt.subplot(2, 2, 3)
sns.barplot(Data_Agg, x= 'media_margin_category', y= 'CPC', palette= 'bright')
plt.xlabel('Media Margin Category', fontsize= 10)
plt.title('', fontsize= 15)

plt.subplot(2, 2, 4)
sns.barplot(Data_Agg, x= 'media_margin_category', y= 'churned', palette= 'bright')
plt.xlabel('Media Margin Category', fontsize= 10)
plt.ylabel('Churn rate', fontsize= 10)
plt.title('', fontsize= 15)
plt.subplots_adjust(hspace=0.5, wspace= 0.3)
plt.show()
# Out:
# <ipython-input-249-43df8156787b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(Data_Agg, x= 'media_margin_category', y= 'CTR', palette= 'bright')
# <ipython-input-249-43df8156787b>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(Data_Agg, x = 'media_margin_category', y= 'VTR', palette ='bright')
# <ipython-input-249-43df8156787b>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(Data_Agg, x= 'media_margin_category', y= 'CPC', palette= 'bright')
# <ipython-input-249-43df8156787b>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(Data_Agg, x= 'media_margin_category', y= 'churned', palette= 'bright')

# %% [markdown]
# Since media margin rates have not shown any statistically significant impact on churn or campaign links, we investigate alternative potential drivers of churn. The overlap in error bars suggests that the differences in average media margins across groups may not be meaningful — indicating that the true means could in fact be the same.

# %% [markdown]
# # Alternate Investigations

# %% [markdown]
# A volume-based approach to seeing the Churn values across various categories

# %%
#Automating Cross tabulation

# %%
multivariate_countplot(Data_Agg, 'media_margin_category', 'churned_category', 'Churn by Media Margin Category', 'Media Margin Category', 'Churned', 'blue')

# %% [markdown]
# Here we see that a high Media Margin does not necessarily affect churning outcomes as the high churn rate dispropotionately come from advertisers in the lowest media margin category.

# %%
#Automating Crosstabulation
def crosstab(dataset, variable1, variable2, xlabel, ylabel):
  crosstab = pd.crosstab(dataset[variable1], dataset[variable2])
  crosstab.index.name = xlabel
  crosstab.columns.name = ylabel
  crosstab['Total'] = crosstab.sum(axis=1)
  crosstab.loc['Total'] = crosstab.sum(axis=0)
  crosstab['% of churned'] = (crosstab[ylabel]/74) * 100
  crosstab['Churn Rate'] = (crosstab['Churned']/crosstab['Total']) * 100
  crosstab['% of Total'] = (crosstab['Total']/181) * 100
  crosstab['Distance From Mean'] = crosstab['Churn Rate'] - crosstab['Churn Rate'].mean()
  crosstab['SD from mean'] = round(crosstab['Distance From Mean']/crosstab['Churn Rate'].std(),2)
  crosstab = crosstab.sort_values(by= 'SD from mean', ascending= False) #Sorting by standard deviation to show dispersion around the mean
  return crosstab

# %%
#Assessing Churn Via Media Margin Category
crosstab(Data_Agg, 'media_margin_category', 'churned_category', 'Media Margin Category', 'Churned')

# %%
#Assessing Churn Via Vertical
crosstab(Data_Agg, 'vertical', 'churned_category', 'Vertical', 'Churned')
#crosstab.sort_values(by= 'SD from mean', ascending= False)
#Sort by SD mean

# %%
#Assesisng Churn by Tier
crosstab(Data_Agg, 'tier', 'churned_category', 'Tier', 'Churned')

# %% [markdown]
# #Creating ML model to find drivers of churn.

# %%
from sklearn.preprocessing import RobustScaler #Excellent for scaling Data with non-normal and skewed distributions
from sklearn.model_selection import train_test_split #To split the data into training and testing buckets
from sklearn.linear_model import LogisticRegression #Model for feature direction
from sklearn.ensemble import RandomForestClassifier #Model for size of impact
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report #model accuracy assessment
from statsmodels.stats.outliers_influence import variance_inflation_factor #Variance Inflation Factor - To fulfil multicollinearity assumptions

# %%
#Selecting the numerical variables
numerical_variables = Data_Agg.select_dtypes(include=[np.number])

numerical_variables.columns

# %%
#Splitting Data into dependent and independent variables and removing variables that could cause data leakage
X = numerical_variables.drop(['churned', 'months_since_last_transaction'], axis = 1)
y = numerical_variables['churned']

# %%
#Variance inflation factor for dependent variables - To fulfill multicollinearit assumption of the Logistic Regression Model
VIF = pd.DataFrame()
VIF['variables'] = X.columns
VIF['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
VIF

# %%
#Given this VIF we drop
X = X.drop(['media_cost', 'data_revenue', 'gross_spend'], axis = 1)
VIF = pd.DataFrame()
VIF['variables'] = X.columns
VIF['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
VIF

# %%
#Scaling the dependent variables
scaler = RobustScaler() # We use robust scaler as the relevant data lacks a normal distribution
X_scaled = scaler.fit_transform(X)
#converting them back into dataframe
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
#Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
#Fitting the data onto the model
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
##printing coefficient
Coefficients = pd.DataFrame({'Feature': X.columns, 'Coefficient': model.coef_[0]})
Coefficients['Odds Ratio'] = np.exp(Coefficients['Coefficient'])
Coefficients['% Change in odds of churn outcome'] = (Coefficients['Odds Ratio'] - 1) * 100
Coefficients.sort_values(by= '% Change in odds of churn outcome', ascending= True)
Coefficients_ = Coefficients[['Feature','% Change in odds of churn outcome']]
Coefficients_.sort_values(by= '% Change in odds of churn outcome', ascending= True)

# %%
model.score(X_test, y_test)

# %%
#Classification Matrix
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)

# %%
#Recall, Precision, F1 Scors
print(classification_report(y_test, y_pred))

# %%
#For further illumination on the magnitude of the variables we build a Random Forest model
RF = RandomForestClassifier()
RF.fit(X_train, y_train)

# %%
RF_coefs = pd.DataFrame({'Feature': X.columns, 'Importance': RF.feature_importances_})
RF_coefs.sort_values(by= 'Importance', ascending= False)

# %%
RF.score(X_test, y_test) #accuracy for random forest

# %%
y_pred = RF.predict(X_test)
confusion_matrix(y_test, y_pred)

# %%
#Recall, Precision and F1 Score
print(classification_report(y_test, y_pred)) #
